# %%
import pandas as pd

train = pd.read_csv("data/Training.csv")

train.head()
# Out:
#   Swahili word     Stem
# 0    ataharibu  -harib-
# 1       pigiwa     pig-
# 2  alipompokea   -poke-
# 3   usijitumie    -tum-
# 4  ungalicheza   -chez-
